# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd

# %% [markdown]
# # Loading Sample Data

# %%
sample_df = pd.read_excel('sampledatafoodsales.xlsx', sheet_name='FoodSales')
sample_df
# Out:
#           ID       Date Region         City  Category         Product  Qty  \
# 0    ID07351 2022-01-01   East       Boston      Bars          Carrot   33
# 1    ID07352 2022-01-04   East       Boston  Crackers     Whole Wheat   87
# 2    ID07353 2022-01-07   West  Los Angeles   Cookies  Chocolate Chip   58
# 3    ID07354 2022-01-10   East     New York   Cookies  Chocolate Chip   82
# 4    ID07355 2022-01-13   East       Boston   Cookies       Arrowroot   38
# ..       ...        ...    ...          ...       ...             ...  ...
# 239  ID07590 2023-12-18   East       Boston   Cookies       Arrowroot   34
# 240  ID07591 2023-12-21   East       Boston   Cookies  Chocolate Chip  245
# 241  ID07592 2023-12-24   East       Boston  Crackers     Whole Wheat   30
# 242  ID07593 2023-12-27   West  Los Angeles      Bars            Bran   30
# 243  ID07594 2023-12-30   West  Los Angeles   Cookies  Oatmeal Raisin   44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# ...

# %% [markdown]
# # Pandas Dataframes

# %% [markdown]
# ## Creating dataframe (df) from dictionary

# %%
df = pd.DataFrame(data={'a':[1, 2], 'b':[3, 4]})
df
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
df = pd.DataFrame(data={'a':[1, 2], 'b':[3, 4]}, index=['i', 'ii'])
df
# Out:
#     a  b
# i   1  3
# ii  2  4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Creating df from a Pandas Series (ds)

# %%
ds = pd.Series([1, 2, 3, 4, 5])
ds
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(ds)
# Out:
# pandas.core.series.Series

# %%
df = pd.DataFrame(ds)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df = pd.DataFrame(ds, columns=['col_1'])
df
# Out:
#    col_1
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %% [markdown]
# ## Dataframe Summary

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          244 non-null    object
#  1   Date        244 non-null    datetime64[ns]
#  2   Region      244 non-null    object
#  3   City        244 non-null    object
#  4   Category    244 non-null    object
#  5   Product     244 non-null    object
#  6   Qty         244 non-null    int64
#  7   UnitPrice   244 non-null    float64
#  8   TotalPrice  244 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 17.3+ KB

# %% [markdown]
# ## Dataframe Type

# %%
type(sample_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Columnwise Datatypes in the df

# %%
sample_df.dtypes
# Out:
# ID                    object
# Date          datetime64[ns]
# Region                object
# City                  object
# Category              object
# Product               object
# Qty                    int64
# UnitPrice            float64
# TotalPrice           float64
# dtype: object

# %% [markdown]
# ## To get Top ‘n’ rows of a df

# %%
sample_df.head()
# Out:
#         ID       Date Region         City  Category         Product  Qty  \
# 0  ID07351 2022-01-01   East       Boston      Bars          Carrot   33
# 1  ID07352 2022-01-04   East       Boston  Crackers     Whole Wheat   87
# 2  ID07353 2022-01-07   West  Los Angeles   Cookies  Chocolate Chip   58
# 3  ID07354 2022-01-10   East     New York   Cookies  Chocolate Chip   82
# 4  ID07355 2022-01-13   East       Boston   Cookies       Arrowroot   38
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84

# %%
sample_df.head(7)
# Out:
#         ID       Date Region         City  Category         Product  Qty  \
# 0  ID07351 2022-01-01   East       Boston      Bars          Carrot   33
# 1  ID07352 2022-01-04   East       Boston  Crackers     Whole Wheat   87
# 2  ID07353 2022-01-07   West  Los Angeles   Cookies  Chocolate Chip   58
# 3  ID07354 2022-01-10   East     New York   Cookies  Chocolate Chip   82
# 4  ID07355 2022-01-13   East       Boston   Cookies       Arrowroot   38
# 5  ID07356 2022-01-16   East       Boston      Bars          Carrot   54
# 6  ID07357 2022-01-19   East       Boston  Crackers     Whole Wheat  149
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84
# 5       1.77       95.58
# 6       3.49      520.01

# %% [markdown]
# ## To get Last ‘n’ rows of a df

# %%
sample_df.tail()
# Out:
#           ID       Date Region         City  Category         Product  Qty  \
# 239  ID07590 2023-12-18   East       Boston   Cookies       Arrowroot   34
# 240  ID07591 2023-12-21   East       Boston   Cookies  Chocolate Chip  245
# 241  ID07592 2023-12-24   East       Boston  Crackers     Whole Wheat   30
# 242  ID07593 2023-12-27   West  Los Angeles      Bars            Bran   30
# 243  ID07594 2023-12-30   West  Los Angeles   Cookies  Oatmeal Raisin   44
#
#      UnitPrice  TotalPrice
# 239       2.18       74.12
# 240       1.87      458.15
# 241       3.49      104.70
# 242       1.87       56.10
# 243       2.84      124.96

# %%
sample_df.tail(7)
# Out:
#           ID       Date Region         City  Category         Product  Qty  \
# 237  ID07588 2023-12-12   East     New York  Crackers     Whole Wheat   25
# 238  ID07589 2023-12-15   West    San Diego   Cookies  Chocolate Chip   96
# 239  ID07590 2023-12-18   East       Boston   Cookies       Arrowroot   34
# 240  ID07591 2023-12-21   East       Boston   Cookies  Chocolate Chip  245
# 241  ID07592 2023-12-24   East       Boston  Crackers     Whole Wheat   30
# 242  ID07593 2023-12-27   West  Los Angeles      Bars            Bran   30
# 243  ID07594 2023-12-30   West  Los Angeles   Cookies  Oatmeal Raisin   44
#
#      UnitPrice  TotalPrice
# 237       3.49       87.25
# 238       1.87      179.52
# 239       2.18       74.12
# 240       1.87      458.15
# 241       3.49      104.70
# 242       1.87       56.10
# 243       2.84      124.96
